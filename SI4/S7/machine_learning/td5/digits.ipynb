# %% [markdown]
# # Logistic regression
#
# - dataset : digits
#     - split train/valid/test
#     - learn the classification
#     - how to use valid set for stopping the learning ?
#     - which method for multiclass ?
#     - compare with decision trees

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split

X, y = datasets.load_digits(return_X_y=True)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=6000)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print(f"train score: {model.score(X_train, y_train)}")
print(f"test score: {model.score(X_test, y_test)}")
# Out:
# train score: 1.0
# test score: 0.9733333333333334

# %% [markdown]
#  - evaluate the classification (train score, valid/test score)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=range(10))
disp.plot(cmap=plt.cm.Blues)
